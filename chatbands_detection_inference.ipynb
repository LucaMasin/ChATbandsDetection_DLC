# %%
import deeplabcut
import os
os.chdir('./unsupervised-pretraining-deeplabcut')
import chatbands
from chatbands import extract_labeled_data
from chatbands import extract_unlabeled_data
from chatbands import predict_chAT
from chatbands import make_labeled_tif
from modified.trainingsetmanipulation import create_training_dataset as pose_training_set

# %% [markdown]
# **For more information on the specifications and used parameters of the DeepLabCut model, look at the deeplabcut_fullguide.pdf in /home/bram/chatbands**

# %% [markdown]
# # Inference
# In the following code, new data is analyzed using the trained model. Predictions are made every **step_size** pixels along the slices (If yo.
# Set the following variables:
# **inference_path**: the folder with tif files that need to be analyzed. All tif files in this folder will be analyzed.
# **config_path**: the path to the config.yaml file of the project in which the trained model is located that you want to use.
# **dest_path**: the folder in which the results should be placed.
#
# In the **dest_path** folder, a folder is created for the results of each tif file. Extra files are created, but these are the predictions for the subimages. You can remove these if you want.

# %%
#inference_path = "/home/bram/chatbands/data/inference"
#dest_path = "/home/bram/chatbands/results"
step_size = 40 # Change step_size if needed
inference_path = "/media/areca/LabPapers/SCGad/Data/singleRGCs/deeplabcutChAT_todo"
dest_path = "/media/areca/LabPapers/SCGad/Data/singleRGCs/deeplabcutChAT_ori"
config_path = "/home/bram/chatbands/unsupervised-pretraining-deeplabcut/chATbands-NERF-2019-11-29/config.yaml" # Comment if new projectdest_path = "/home/bram/chatbands/results"
chatbands = [f.split('_chAT')[0] for f in os.listdir(inference_path) if f.endswith('.tif')]
extract_unlabeled_data.extract_video(chatbands, inference_path, config_path, step_size=step_size) # Change step_size if needed
# Out:
# (197, 386, 386)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (217, 724, 717)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (213, 388, 714)
# Normal axis
# Modified axis
# (330, 387, 717)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (260, 717, 717)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (332, 718, 720)
# Normal axis
# Modified axis
# (333, 721, 717)
# Normal axis
# Modified axis
# (218, 720, 717)
# Normal axis
# Modified axis
# (218, 720, 714)
# Normal axis
# Modified axis

# %% [markdown]
# Again, choose the step_size. This step_size should always correspond to the step_size in the previous step. Using the **create_video** and **create_tif** options, you can choose to generate a video or tif file for which the predictions of the model are mapped onto the slices.

# %%
chatbands = [(f.split('video')[1]).split('.mp4')[0] for f in os.listdir(os.path.join(project_path, 'subimages')) if f.endswith('.mp4')]

predict_chAT.analyze_videos(config_path, gputouse=0. videos=None, videotype='mp4', save_as_csv=True, destfolder=dest_path)
for chat in chatbands:
    predict_chAT.get_slice_results(os.path.join(inference_path, "{}_chAT_STD.tif".format(chat)), os.path.join(dest_path, [f for f in os.listdir(dest_path) if f.endswith('.h5') and chat in f][0]), 
                                       dest_path, step_size=step_size, create_video=False, create_tif=True) # Change step_size if needed
# Out:
# Using snapshot-510000 for model /home/bram/chatbands/unsupervised-pretraining-deeplabcut/chATbands-NERF-2019-11-29/dlc-models/iteration-0/chATbandsNov29-trainset80shuffle1
# shape:  Tensor("pose/Shape:0", shape=(4,), dtype=int32)
# shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[3,3,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/TruncatedNormal = TruncatedNormal[T=DT_INT32, _class=["loc:@resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Assign"], dtype=DT_FLOAT, seed=0, seed2=0, _device="/job:localhost/replica:0/task:0/device:GPU:0"](resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-3-4909cc9bef9b> in <module>()
# ----> 1 predict_chAT.analyze_videos(config_path, videos=None, videotype='mp4', save_as_csv=False, destfolder=dest_path)
#       2 for chat in chatbands:
#       3     predict_chAT.get_slice_results(os.path.join(inference_path, "{}_chAT_STD.tif".format(chat)), os.path.join(dest_path, [f for f in os.listdir(dest_path) if f.endswith('.h5') and chat in f][0]),
#       4                                        dest_path, step_size=40, create_video=False, create_tif=True) # Change step_size if needed
#
# /home/bram/chatbands/unsupervised-pretraining-deeplabcut/chatbands/predict_chAT.py in analyze_videos(config, videos, videotype, shuffle, trainingsetindex, gputouse, save_as_csv, destfolder)
#     139     DLCscorer = auxiliaryfunctions.GetScorerName(cfg,shuffle,trainFraction,trainingsiterations=trainingsiterations)
#     140
# --> 141     sess, inputs, outputs = predict.setup_pose_prediction(dlc_cfg)
#     142     pdindex = pd.MultiIndex.from_product([[DLCscorer], dlc_cfg['all_joints_names'], ['x', 'y', 'likelihood']],names=['scorer', 'bodyparts', 'coords'])
#     143
#
# /home/bram/chatbands/unsupervised-pretraining-deeplabcut/modified/predict.py in setup_pose_prediction(cfg)
#      22     restorer = tf.train.Saver()
#      23     sess = tf.Session()
# ---> 24     sess.run(tf.global_variables_initializer())
#      25     sess.run(tf.local_variables_initializer())
#      26
#
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[3,3,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/TruncatedNormal = TruncatedNormal[T=DT_INT32, _class=["loc:@resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Assign"], dtype=DT_FLOAT, seed=0, seed2=0, _device="/job:localhost/replica:0/task:0/device:GPU:0"](resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/TruncatedNormal', defined at:
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 377, in dispatch_queue
#     yield self.process_one()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 714, in __init__
#     self.run()
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/bram/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2683, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/bram/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2787, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/bram/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2847, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-4909cc9bef9b>", line 1, in <module>
#     predict_chAT.analyze_videos(config_path, videos=None, videotype='mp4', save_as_csv=False, destfolder=dest_path)
#   File "/home/bram/chatbands/unsupervised-pretraining-deeplabcut/chatbands/predict_chAT.py", line 141, in analyze_videos
#     sess, inputs, outputs = predict.setup_pose_prediction(dlc_cfg)
#   File "/home/bram/chatbands/unsupervised-pretraining-deeplabcut/modified/predict.py", line 17, in setup_pose_prediction
#     net_heads = (pose_net.PoseNet(cfg)).test(inputs)
#   File "/home/bram/chatbands/unsupervised-pretraining-deeplabcut/modified/pose_net.py", line 124, in test
#     heads = self.get_net(inputs)
#   File "/home/bram/chatbands/unsupervised-pretraining-deeplabcut/modified/pose_net.py", line 120, in get_net
#     net, end_points = self.extract_features(inputs)
#   File "/home/bram/chatbands/unsupervised-pretraining-deeplabcut/modified/pose_net.py", line 62, in extract_features
#     global_pool=False, output_stride=16,is_training=False, reuse=tf.AUTO_REUSE) #TODO: check is_training and reuse
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py", line 274, in resnet_v1_50
#     scope=scope)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py", line 207, in resnet_v1
#     net = resnet_utils.stack_blocks_dense(net, blocks, output_stride)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py", line 183, in func_with_args
#     return func(*args, **current_args)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/slim/python/slim/nets/resnet_utils.py", line 211, in stack_blocks_dense
#     net = block.unit_fn(net, rate=rate, **dict(unit, stride=1))
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py", line 183, in func_with_args
#     return func(*args, **current_args)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py", line 119, in bottleneck
#     residual, depth_bottleneck, 3, stride, rate=rate, scope='conv2')
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/slim/python/slim/nets/resnet_utils.py", line 131, in conv2d_same
#     scope=scope)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py", line 183, in func_with_args
#     return func(*args, **current_args)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py", line 1049, in convolution
#     outputs = layer.apply(inputs)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/layers/base.py", line 828, in apply
#     return self.__call__(inputs, *args, **kwargs)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/layers/base.py", line 699, in __call__
#     self.build(input_shapes)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/layers/convolutional.py", line 144, in build
#     dtype=self.dtype)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/layers/base.py", line 546, in add_variable
#     partitioner=partitioner)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/training/checkpointable.py", line 436, in _add_variable_with_custom_getter
#     **kwargs_for_getter)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 1317, in get_variable
#     constraint=constraint)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 1079, in get_variable
#     constraint=constraint)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 417, in get_variable
#     return custom_getter(**custom_getter_kwargs)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py", line 1611, in layer_variable_getter
#     return _model_variable_getter(getter, *args, **kwargs)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py", line 1602, in _model_variable_getter
#     use_resource=use_resource)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py", line 183, in func_with_args
#     return func(*args, **current_args)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/variables.py", line 291, in model_variable
#     use_resource=use_resource)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py", line 183, in func_with_args
#     return func(*args, **current_args)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/variables.py", line 246, in variable
#     use_resource=use_resource)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 394, in _true_getter
#     use_resource=use_resource, constraint=constraint)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 786, in _get_single_variable
#     use_resource=use_resource)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 2220, in variable
#     use_resource=use_resource)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 2210, in <lambda>
#     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 2193, in default_variable_creator
#     constraint=constraint)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 235, in __init__
#     constraint=constraint)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 343, in _init_from_args
#     initial_value(), name="initial_value", dtype=dtype)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 770, in <lambda>
#     shape.as_list(), dtype=dtype, partition_info=partition_info)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/initializers.py", line 150, in _initializer
#     seed=seed)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/random_ops.py", line 174, in truncated_normal
#     shape_tensor, dtype, seed=seed1, seed2=seed2)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/ops/gen_random_ops.py", line 850, in truncated_normal
#     name=name)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/home/bram/.conda/envs/mousetracker/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[3,3,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/TruncatedNormal = TruncatedNormal[T=DT_INT32, _class=["loc:@resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Assign"], dtype=DT_FLOAT, seed=0, seed2=0, _device="/job:localhost/replica:0/task:0/device:GPU:0"](resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
